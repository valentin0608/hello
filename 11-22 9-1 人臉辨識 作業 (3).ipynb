# %%
# !pip install Cmake
# Out:
# ...
#    ---------------------------------------- 0.0/36.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.4 MB 281.8 kB/s eta 0:02:10
#    ---------------------------------------- 0.1/36.4 MB 363.1 kB/s eta 0:01:41
#    ---------------------------------------- 0.1/36.4 MB 435.7 kB/s eta 0:01:24
#    ---------------------------------------- 0.2/36.4 MB 696.3 kB/s eta 0:00:53
#    ---------------------------------------- 0.2/36.4 MB 724.0 kB/s eta 0:00:50
#    ---------------------------------------- 0.3/36.4 MB 803.7 kB/s eta 0:00:45
#    ---------------------------------------- 0.3/36.4 MB 873.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.4/36.4 MB 888.4 kB/s eta 0:00:41
# ...

# %%
# !pip install face_recognition
# Out:
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...

# %%
# !pip install face_recognition --no-deps

# %%
# !pip install dlib

# %%
import face_recognition

# %%
import matplotlib.pyplot as plt

# %%
image = face_recognition.load_image_file('C:/Users/user/Downloads/Trump_Xi_Kim.jpg')
face_locations = face_recognition.face_locations(image)
plt.imshow(image)

# %%
print(f'There are {len(face_locations)} people in this image')
# Out:
# There are 3 people in this image

# %%
import face_recognition

# %%
image_of_person=face_recognition.load_image_file('C:/Users/user/Downloads/Trump_Xi_Kim.jpg')
person_face_encoding=face_recognition.face_encodings(image_of_person)[0]
plt.imshow(image_of_person)

# %%
unknown_image=face_recognition.load_image_file('C:/Users/user/Downloads/Trump_Xi_Kim.jpg')
unknown_face_encoding=face_recognition.face_encodings(unknown_image)[0]
plt.imshow(unknown_image)

# %%
results = face_recognition.compare_faces([person_face_encoding], unknown_face_encoding)

# %%
if results[0]:
    print('This is Fa')
else:
    print('This is NOT Fa')
# Out:
# This is Fa

# %%
from PIL import Image
import face_recognition
import matplotlib.pyplot as plt

# %%
Image=face_recognition.load_image_file('C:/Users/user/Downloads/Trump_Xi_Kim.jpg')
face_locations=face_recognition.face_locations(image)

# %%
num=1
for face_location in face_locations:
    top, right, bottom, left = face_location
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    pil_image.show()
    filename = "face" + str(num) + ".jpg"
    pil_image.save('C:/Users/user/Downloads/Trump_Xi_Kim.jpg')
    num += 1

# %%
import face_recognition
from PIL import Image, ImageDraw

# %%
image_of_Fa = face_recognition.load_image_file('C:/Users/user/Downloads/face1.jpg')
Fa_face_encoding = face_recognition.face_encodings(image_of_Fa)[0]
plt.imshow(image_of_Fa)

# %%
image_of_Esther = face_recognition.load_image_file('C:/Users/user/Downloads/face2.jpg')
Esther_face_encoding = face_recognition.face_encodings(image_of_Esther)[0]
plt.imshow(image_of_Esther)

# %%
image_of_Esther = face_recognition.load_image_file('C:/Users/user/Downloads/face3.jpg')
Winston_face_encoding = face_recognition.face_encodings(image_of_Esther)[0]
plt.imshow(image_of_Esther)

# %%
known_face_encodings = [Fa_face_encoding, Winston_face_encoding]
known_face_names = ["Fa", "Winston"]

# %%
test_image = face_recognition.load_image_file('C:/Users/user/Downloads/leader.jpg')
plt.imshow(test_image)

# %%
face_locations = face_recognition.face_locations(test_image)
face_encodings = face_recognition.face_encodings(test_image, face_locations)

# %%
pil_image = Image.fromarray(test_image)
draw = ImageDraw.Draw(pil_image)

# %%
from PIL import ImageFont

# 如果需要字體，可以使用 ImageFont 加載默認或指定的字體
font = ImageFont.load_default()

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
    name = "unknown Person"
    
    if True in matches:
        first_match_index = matches.index(True)
        name = known_face_names[first_match_index]

# %%
   # 繪製方框與邊框之邊線(outline)顏色
draw.rectangle(((left, top), (right, bottom)), outline=(0, 0, 0))

# %%
text_bbox = font.getbbox(name)
text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]

# %%
draw.rectangle(((left, bottom - text_height - 8), (right, bottom)), fill=(0, 255, 0), outline=(0, 0, 0))

# %%
draw.text((left + 6, bottom - text_height - 6), name, font=font, fill=(0, 0, 0))

# %%
pil_image.show()
pil_image.save('C:/Users/user/Downloads/leader.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7476/4260387510.py in <module>
# ----> 1 pil_image.show()
#       2 pil_image.save('C:/Users/user/Downloads/leader.jpg')
#
# NameError: name 'pil_image' is not defined
