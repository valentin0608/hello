# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import yfinance as yf
import pandas as pd

# %%
tickers_list=["GOOG","TSLA","MSFT"]

# %%
data=pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
    data[ticker]=yf.download(ticker, period='10y',interval='1d')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  GOOG       TSLA       MSFT
# Date
# 2014-09-22  29.216339  16.668667  40.237186
# 2014-09-23  28.905956  16.694000  39.809681
# 2014-09-24  29.247179  16.809334  40.254295
# 2014-09-25  28.604027  16.463333  39.365070
# 2014-09-26  28.705500  16.440001  39.681435

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.title('Adjusted Close Price', fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('year', fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
import os
print(os.getcwd())  # 顯示當前工作目錄
# Out:
# C:\Users\user
